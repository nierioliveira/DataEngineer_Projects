# %% [markdown]
# ## Conhecendo a biblioteca Requests

# %% [markdown]
# # Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %% [markdown]
# # Alguns retornos da API

# %% [markdown]
# JSON

# %%
data = r.json()
print(data)
# Out:
# [{'id': '39637165812', 'type': 'CreateEvent', 'actor': {'id': 145258315, 'login': 'power10101', 'display_login': 'power10101', 'gravatar_id': '', 'url': 'https://api.github.com/users/power10101', 'avatar_url': 'https://avatars.githubusercontent.com/u/145258315?'}, 'repo': {'id': 820429712, 'name': 'power10101/QXJjaGRlbW9uIFMwMUUwMy5tcDQ', 'url': 'https://api.github.com/repos/power10101/QXJjaGRlbW9uIFMwMUUwMy5tcDQ'}, 'payload': {'ref': None, 'ref_type': 'repository', 'master_branch': 'main', 'description': None, 'pusher_type': 'user'}, 'public': True, 'created_at': '2024-06-26T12:58:47Z'}, {'id': '39637165813', 'type': 'CreateEvent', 'actor': {'id': 147038466, 'login': 'Stefy2024', 'display_login': 'Stefy2024', 'gravatar_id': '', 'url': 'https://api.github.com/users/Stefy2024', 'avatar_url': 'https://avatars.githubusercontent.com/u/147038466?'}, 'repo': {'id': 820429714, 'name': 'Stefy2024/Chic-Dressing', 'url': 'https://api.github.com/repos/Stefy2024/Chic-Dressing'}, 'payload': {'ref
# ...

# %%
r.json()
# Out:
# [{'id': '39637165812',
#   'type': 'CreateEvent',
#   'actor': {'id': 145258315,
#    'login': 'power10101',
#    'display_login': 'power10101',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/power10101',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/145258315?'},
#   'repo': {'id': 820429712,
#    'name': 'power10101/QXJjaGRlbW9uIFMwMUUwMy5tcDQ',
#    'url': 'https://api.github.com/repos/power10101/QXJjaGRlbW9uIFMwMUUwMy5tcDQ'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-06-26T12:58:47Z'},
#  {'id': '39637165813',
#   'type': 'CreateEvent',
#   'actor': {'id': 147038466,
#    'login': 'Stefy2024',
#    'display_login': 'Stefy2024',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Stefy2024',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/147038466?'},
# ...

# %% [markdown]
# TEXT

# %%
r.text
# Out:
# '[{"id":"39637165812","type":"CreateEvent","actor":{"id":145258315,"login":"power10101","display_login":"power10101","gravatar_id":"","url":"https://api.github.com/users/power10101","avatar_url":"https://avatars.githubusercontent.com/u/145258315?"},"repo":{"id":820429712,"name":"power10101/QXJjaGRlbW9uIFMwMUUwMy5tcDQ","url":"https://api.github.com/repos/power10101/QXJjaGRlbW9uIFMwMUUwMy5tcDQ"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2024-06-26T12:58:47Z"},{"id":"39637165813","type":"CreateEvent","actor":{"id":147038466,"login":"Stefy2024","display_login":"Stefy2024","gravatar_id":"","url":"https://api.github.com/users/Stefy2024","avatar_url":"https://avatars.githubusercontent.com/u/147038466?"},"repo":{"id":820429714,"name":"Stefy2024/Chic-Dressing","url":"https://api.github.com/repos/Stefy2024/Chic-Dressing"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","descript
# ...

# %% [markdown]
# STATUS_CODE

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# URL REQUISITADA

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %% [markdown]
# # Testando outro endpoints

# %%
n = requests.get('https://api.github.com/versions')
n.status_code
# Out:
# 200

# %%
n.url
# Out:
# 'https://api.github.com/versions'

# %%
n.json()
# Out:
# ['2022-11-28']
